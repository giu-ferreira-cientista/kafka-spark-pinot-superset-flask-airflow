# %%
from kafka import KafkaConsumer, KafkaProducer
import os
import json
import uuid
from concurrent.futures import ThreadPoolExecutor
TOPIC_NAME = "EMAIL"
KAFKA_SERVER = "kafka-server:29092"

# %%
consumer = KafkaConsumer(
    TOPIC_NAME,
    bootstrap_servers=[KAFKA_SERVER],
    auto_offset_reset='earliest',
    enable_auto_commit=False,
    # to deserialize kafka.producer.object into dict
    #value_deserializer=lambda m: json.loads(m.decode('utf-8')),
)

# %%
def sendEmail(data):
    # process steps
    print(data)
    print("E-mail Enviado para o Médico...")

# %%
for email in consumer:
	
	email_data = email.value
	
	sendEmail(email_data)

    
# Parallelism
#with ThreadPoolExecutor(4) as tpool:

#	for email in consumer:

#		email_data = email.value

#		future = tpool.submit(sendEmail, email_data)
# Out:
# b'{"eventTime":"2022-03-01 05:50:00","nome":"joao","avgbpm":42.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-03 01:50:00","nome":"joao","avgbpm":111.0,"avgtemp":35.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-06 03:00:00","nome":"maria","avgbpm":69.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-06 15:10:00","nome":"joao","avgbpm":64.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-07 03:15:00","nome":"antonio","avgbpm":55.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-07 07:25:00","nome":"joao","avgbpm":70.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-09 03:30:00","nome":"maria","avgbpm":85.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-13 01:35:00","nome":"maria","avgbpm":107.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-14 23:30:00","nome":"maria","avgbpm":92.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-17 13:40:00","nome":"antonio","avgbpm":60.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-19 01:00:00","nome":"maria","avgbpm":83.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-19 23:45:00","nome":"joao","avgbpm":52.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-21 16:35:00","nome":"maria","avgbpm":94.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-22 14:50:00","nome":"maria","avgbpm":122.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-22 16:35:00","nome":"joao","avgbpm":49.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-25 04:05:00","nome":"joao","avgbpm":87.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-27 15:55:00","nome":"joao","avgbpm":60.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-30 08:45:00","nome":"maria","avgbpm":74.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-01 05:50:00","nome":"joao","avgbpm":42.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-03 01:50:00","nome":"joao","avgbpm":111.0,"avgtemp":35.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-06 03:00:00","nome":"maria","avgbpm":69.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-06 15:10:00","nome":"joao","avgbpm":64.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-07 03:15:00","nome":"antonio","avgbpm":55.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-07 07:25:00","nome":"joao","avgbpm":70.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-09 03:30:00","nome":"maria","avgbpm":85.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-13 01:35:00","nome":"maria","avgbpm":107.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-14 23:30:00","nome":"maria","avgbpm":92.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-17 13:40:00","nome":"antonio","avgbpm":60.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-19 01:00:00","nome":"maria","avgbpm":83.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-19 23:45:00","nome":"joao","avgbpm":52.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-21 16:35:00","nome":"maria","avgbpm":94.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-22 14:50:00","nome":"maria","avgbpm":122.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-22 16:35:00","nome":"joao","avgbpm":49.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-25 04:05:00","nome":"joao","avgbpm":87.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-27 15:55:00","nome":"joao","avgbpm":60.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-30 08:45:00","nome":"maria","avgbpm":74.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-01 05:50:00","nome":"joao","avgbpm":42.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-03 01:50:00","nome":"joao","avgbpm":111.0,"avgtemp":35.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-06 03:00:00","nome":"maria","avgbpm":69.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-06 15:10:00","nome":"joao","avgbpm":64.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-07 03:15:00","nome":"antonio","avgbpm":55.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-07 07:25:00","nome":"joao","avgbpm":70.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-09 03:30:00","nome":"maria","avgbpm":85.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-13 01:35:00","nome":"maria","avgbpm":107.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-14 23:30:00","nome":"maria","avgbpm":92.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-17 13:40:00","nome":"antonio","avgbpm":60.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-19 01:00:00","nome":"maria","avgbpm":83.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-19 23:45:00","nome":"joao","avgbpm":52.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-21 16:35:00","nome":"maria","avgbpm":94.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-22 14:50:00","nome":"maria","avgbpm":122.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-22 16:35:00","nome":"joao","avgbpm":49.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-25 04:05:00","nome":"joao","avgbpm":87.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-27 15:55:00","nome":"joao","avgbpm":60.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-30 08:45:00","nome":"maria","avgbpm":74.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-01 05:50:00","nome":"joao","avgbpm":42.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-03 01:50:00","nome":"joao","avgbpm":111.0,"avgtemp":35.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-06 03:00:00","nome":"maria","avgbpm":69.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-06 15:10:00","nome":"joao","avgbpm":64.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-07 03:15:00","nome":"antonio","avgbpm":55.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-07 07:25:00","nome":"joao","avgbpm":70.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-09 03:30:00","nome":"maria","avgbpm":85.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-13 01:35:00","nome":"maria","avgbpm":107.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-14 23:30:00","nome":"maria","avgbpm":92.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-17 13:40:00","nome":"antonio","avgbpm":60.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-19 01:00:00","nome":"maria","avgbpm":83.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-19 23:45:00","nome":"joao","avgbpm":52.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-21 16:35:00","nome":"maria","avgbpm":94.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-22 14:50:00","nome":"maria","avgbpm":122.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-22 16:35:00","nome":"joao","avgbpm":49.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-25 04:05:00","nome":"joao","avgbpm":87.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-27 15:55:00","nome":"joao","avgbpm":60.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-30 08:45:00","nome":"maria","avgbpm":74.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-01 05:50:00","nome":"joao","avgbpm":42.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-02 12:50:00","nome":"maria","avgbpm":97.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-03 01:50:00","nome":"joao","avgbpm":111.0,"avgtemp":35.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-06 03:00:00","nome":"maria","avgbpm":69.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-06 15:10:00","nome":"joao","avgbpm":64.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-07 03:15:00","nome":"antonio","avgbpm":55.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-07 07:25:00","nome":"joao","avgbpm":70.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-07 12:15:00","nome":"maria","avgbpm":80.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-08 17:35:00","nome":"joao","avgbpm":91.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-09 03:30:00","nome":"maria","avgbpm":85.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-11 17:00:00","nome":"joao","avgbpm":78.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-13 01:35:00","nome":"maria","avgbpm":107.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-14 23:30:00","nome":"maria","avgbpm":92.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-17 13:40:00","nome":"antonio","avgbpm":60.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-19 01:00:00","nome":"maria","avgbpm":83.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-19 09:20:00","nome":"maria","avgbpm":62.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-19 23:45:00","nome":"joao","avgbpm":52.0,"avgtemp":36.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-20 10:05:00","nome":"antonio","avgbpm":71.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-21 16:35:00","nome":"maria","avgbpm":94.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-22 14:50:00","nome":"maria","avgbpm":122.0,"avgtemp":34.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-22 16:35:00","nome":"joao","avgbpm":49.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-25 04:05:00","nome":"joao","avgbpm":87.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-27 03:50:00","nome":"maria","avgbpm":71.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-27 15:55:00","nome":"joao","avgbpm":60.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-28 18:05:00","nome":"antonio","avgbpm":79.0,"avgtemp":35.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-29 06:50:00","nome":"antonio","avgbpm":48.0,"avgtemp":38.0}'
# E-mail Enviado para o Médico...
# b'{"eventTime":"2022-03-30 08:45:00","nome":"maria","avgbpm":74.0,"avgtemp":37.0}'
# E-mail Enviado para o Médico...
