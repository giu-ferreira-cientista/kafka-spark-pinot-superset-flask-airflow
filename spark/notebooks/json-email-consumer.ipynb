# %%
from kafka import KafkaConsumer, KafkaProducer
import os
import json
import uuid
from concurrent.futures import ThreadPoolExecutor
TOPIC_NAME = "EMAIL"
KAFKA_SERVER = "kafka-server:29092"

# %%
consumer = KafkaConsumer(
    TOPIC_NAME,
    bootstrap_servers=[KAFKA_SERVER],
    auto_offset_reset='earliest',
    enable_auto_commit=False,
    # to deserialize kafka.producer.object into dict
    #value_deserializer=lambda m: json.loads(m.decode('utf-8')),
)

# %%
def sendEmail(data):
    # process steps
    print(data)
    print("\nE-mail Enviado para o Médico...\n")

# %%
for email in consumer:
	
	email_data = email.value
	
	sendEmail(email_data)

    
# Parallelism
#with ThreadPoolExecutor(4) as tpool:

#	for email in consumer:

#		email_data = email.value

#		future = tpool.submit(sendEmail, email_data)
# Out:
# b'{"eventTime":"2022-03-06 03:00:00","nome":"maria","avgbpm":69.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-06 15:10:00","nome":"joao","avgbpm":64.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-07 03:15:00","nome":"antonio","avgbpm":55.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-07 07:25:00","nome":"joao","avgbpm":70.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-09 03:30:00","nome":"maria","avgbpm":85.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-12 01:10:00","nome":"maria","avgbpm":81.0,"avgtemp":40.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-13 18:25:00","nome":"joao","avgbpm":75.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-14 23:30:00","nome":"maria","avgbpm":92.0,"avgtemp":35.666666666666664}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-15 03:05:00","nome":"joao","avgbpm":90.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-17 02:50:00","nome":"antonio","avgbpm":76.0,"avgtemp":42.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-17 15:20:00","nome":"antonio","avgbpm":89.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-20 18:00:00","nome":"antonio","avgbpm":56.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-24 12:00:00","nome":"antonio","avgbpm":66.0,"avgtemp":35.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-25 04:05:00","nome":"joao","avgbpm":87.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-26 02:00:00","nome":"antonio","avgbpm":121.0,"avgtemp":40.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-27 15:55:00","nome":"joao","avgbpm":60.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-28 02:40:00","nome":"maria","avgbpm":78.0,"avgtemp":40.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-29 21:15:00","nome":"joao","avgbpm":63.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-30 08:45:00","nome":"maria","avgbpm":74.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-03 16:05:00","nome":"maria","avgbpm":40.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-04 18:35:00","nome":"joao","avgbpm":121.0,"avgtemp":35.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-06 03:00:00","nome":"maria","avgbpm":69.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-06 15:10:00","nome":"joao","avgbpm":64.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-06 18:40:00","nome":"antonio","avgbpm":82.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-07 03:05:00","nome":"antonio","avgbpm":86.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-07 03:15:00","nome":"antonio","avgbpm":55.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-07 07:25:00","nome":"joao","avgbpm":70.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-09 03:30:00","nome":"maria","avgbpm":85.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-11 14:25:00","nome":"maria","avgbpm":123.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-12 01:10:00","nome":"maria","avgbpm":81.0,"avgtemp":40.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-12 22:20:00","nome":"maria","avgbpm":103.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-13 18:25:00","nome":"joao","avgbpm":75.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-14 23:30:00","nome":"maria","avgbpm":92.0,"avgtemp":35.666666666666664}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-15 03:05:00","nome":"joao","avgbpm":90.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-17 02:50:00","nome":"antonio","avgbpm":76.0,"avgtemp":42.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-17 15:20:00","nome":"antonio","avgbpm":89.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-20 18:00:00","nome":"antonio","avgbpm":56.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-21 14:45:00","nome":"maria","avgbpm":95.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-24 12:00:00","nome":"antonio","avgbpm":66.0,"avgtemp":35.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-25 04:05:00","nome":"joao","avgbpm":87.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-26 02:00:00","nome":"antonio","avgbpm":121.0,"avgtemp":40.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-26 03:10:00","nome":"joao","avgbpm":66.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-26 06:25:00","nome":"antonio","avgbpm":78.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-27 15:55:00","nome":"joao","avgbpm":60.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-28 02:40:00","nome":"maria","avgbpm":78.0,"avgtemp":40.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-29 21:15:00","nome":"joao","avgbpm":63.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-30 08:45:00","nome":"maria","avgbpm":74.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-03 16:05:00","nome":"maria","avgbpm":40.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-04 16:50:00","nome":"maria","avgbpm":73.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-04 18:35:00","nome":"joao","avgbpm":121.0,"avgtemp":35.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-05 07:20:00","nome":"antonio","avgbpm":101.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-06 03:00:00","nome":"maria","avgbpm":69.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-06 15:10:00","nome":"joao","avgbpm":64.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-06 18:40:00","nome":"antonio","avgbpm":82.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-07 03:05:00","nome":"antonio","avgbpm":86.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-07 03:15:00","nome":"antonio","avgbpm":55.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-07 06:50:00","nome":"maria","avgbpm":67.0,"avgtemp":35.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-07 07:25:00","nome":"joao","avgbpm":70.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-08 17:25:00","nome":"joao","avgbpm":92.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-09 03:30:00","nome":"maria","avgbpm":85.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-11 14:25:00","nome":"maria","avgbpm":123.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-11 16:10:00","nome":"joao","avgbpm":88.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-11 21:20:00","nome":"maria","avgbpm":46.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-12 01:10:00","nome":"maria","avgbpm":81.0,"avgtemp":40.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-12 22:20:00","nome":"maria","avgbpm":103.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-13 18:25:00","nome":"joao","avgbpm":75.0,"avgtemp":34.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-14 23:30:00","nome":"maria","avgbpm":92.0,"avgtemp":35.666666666666664}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-15 03:05:00","nome":"joao","avgbpm":90.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-17 02:50:00","nome":"antonio","avgbpm":76.0,"avgtemp":42.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-17 15:20:00","nome":"antonio","avgbpm":89.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-20 09:30:00","nome":"antonio","avgbpm":63.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-20 18:00:00","nome":"antonio","avgbpm":56.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-21 14:45:00","nome":"maria","avgbpm":95.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-24 12:00:00","nome":"antonio","avgbpm":66.0,"avgtemp":35.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-25 04:05:00","nome":"joao","avgbpm":87.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-25 10:40:00","nome":"maria","avgbpm":96.0,"avgtemp":35.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-26 02:00:00","nome":"antonio","avgbpm":121.0,"avgtemp":40.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-26 03:10:00","nome":"joao","avgbpm":66.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-26 06:25:00","nome":"antonio","avgbpm":78.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-27 15:55:00","nome":"joao","avgbpm":60.0,"avgtemp":38.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-28 02:40:00","nome":"maria","avgbpm":78.0,"avgtemp":40.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-29 11:45:00","nome":"maria","avgbpm":57.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-29 21:15:00","nome":"joao","avgbpm":63.0,"avgtemp":36.0}'
#
# E-mail Enviado para o Médico...
#
# b'{"eventTime":"2022-03-30 08:45:00","nome":"maria","avgbpm":74.0,"avgtemp":37.0}'
#
# E-mail Enviado para o Médico...
